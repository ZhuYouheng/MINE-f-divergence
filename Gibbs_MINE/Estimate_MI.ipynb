# %%
import json
import matplotlib.pyplot as plt
import numpy as np
p_current = 28
with open("kl_pw_result/p={0}_gaussian_full_beta=10.json".format(p_current), "r") as outfile:
    data = json.load(outfile)
data = data[0:320]
x_plot = [x for x in range(len(data))]
plt.plot(x_plot, data)

# %%
np.mean(data[100:130])
# Out:
# 0.637361737092336

# %%
np.mean(data[200:250])
# Out:
# 0.6301215815544129

# %% [markdown]
# 4 0.257
# 6 0.305
# 8 0.320
# 10 0.417
# 12 0.446
# 14 0.463
# 16 0.518
# 18 0.545
# 20
# 22 0.648
# 24 0.637?
# 26
# 28 0.688
# 30 0.710
