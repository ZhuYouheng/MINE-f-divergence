# %%
import json
with open('data/gibbs_data_p_is_4.json', 'r') as datafile:
    data = json.load(datafile)

# %%
S = [data[i]['S'][0] for i in range(len(data))]
w = [data[i]['w'] for i in range(len(data))]
S
# Out:
# [[-0.9886104508973063,
#   0.4113942952418904,
#   -1.8670940580830013,
#   1.7275517975696557,
#   0.6155826720972213,
#   -0.3645113370540821],
#  [0.9905684526024945,
#   -1.3201481371007764,
#   -1.086102004846899,
#   2.3290102608372885,
#   0.4814497638980405,
#   -0.42959351746307667],
#  [-0.76667783887521,
#   1.2448755884002738,
#   0.9550238093456008,
#   0.1601496857610239,
#   1.2471130099602339,
#   0.33378107660822337],
#  [0.8594012702641215,
#   -0.03923218900628708,
#   1.4267437230480091,
#   -0.0065059874995754335,
#   -0.35851198850650257,
#   -0.080819471458935],
#  [-0.26022429092737337,
#   -0.2857183627212271,
#   -0.8603629499039666,
#   1.0446702647373012,
#   0.9953883937991803,
#   -0.01678193191527405],
#  [1.2464033579897158,
#   -0.8714314607139046,
#   -2.212868766200855,
#   0.41333978278725325,
#   -0.742758374320768,
#   -0.7026891867179618],
#  [-0.3889307929763864,
#   0.7637981709966679,
#   2.061212799322649,
#   0.2405347714477274,
# ...
